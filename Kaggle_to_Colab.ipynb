# %% [markdown]
# <a href="https://colab.research.google.com/github/BieeRamy/Dataset/blob/main/Kaggle_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **How to fletch data from Kaggle to colab without store both in laptop or google drive	**
#
# Step 2: Upload Kaggle API key
# 	from google.colab import files
# 	# This opens a file picker; select your kaggle.json file from Windows(API kaggle)
# 	files.upload()
# Step 3: Configure Kaggle API
# 	!mkdir -p ~/.kaggle
# 	!cp kaggle.json ~/.kaggle/
# 	!chmod 600 ~/.kaggle/kaggle.json
# Step 4: Install Kaggle package
# 	!pip install kaggle
# Step 5: Download the dataset from Kaggle
# 	!kaggle datasets download -d willianoliveiragibin/green-house-gas-emission
# Step 6: Unzip the dataset
# 	!unzip -o green-house-gas-emission.zip -d dataset
# Step 8: Load CSV into pandas
# 	import pandas as pd
# 	df = pd.read_csv('dataset/Green_House_Gas_Emission new.csv')  # match the filename exactly
# 	df.head(5)

# %% [markdown]
# # from kaggle (need to flech data)
#     from google.colab import files
# ---
# # Upload your kaggle.json from Windows
#     files.upload()
# ---
# # Configure Kaggle credentials
#     !mkdir -p ~/.kaggle
#     !cp kaggle.json ~/.kaggle/
#     !chmod 600 ~/.kaggle/kaggle.json
# ---
# # Download dataset using slug
#     #URL = ('/kaggle/input/life-style-data/Final_data.csv') from kaggle
#     #Auhtor: jockeroika
#     #Dataset name: life-style-data
#     !kaggle datasets download -d jockeroika/life-style-data
# ---
# # Unzip the file
#     !unzip -o life-style-data.zip
# ---
# # Load CSV into pandas
#     import pandas as pd
#     df = pd.read_csv('Final_data.csv')
#     df.head(5)

# %%
# from kaggle (need to flech data)
from google.colab import files

# Upload your kaggle.json from Windows
files.upload()
# Out:
#      <input type="file" id="files-b62f3941-0f9f-49ad-b0e2-c3f1c164065b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b62f3941-0f9f-49ad-b0e2-c3f1c164065b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 3️⃣ Configure Kaggle credentials
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# Download dataset using slug
# URL = ('/kaggle/input/life-style-data/Final_data.csv') from kaggle
# Auhtor: jockeroika
# Dataset name: life-style-data
# !kaggle datasets download -d jockeroika/life-style-data
# Unzip the file
# !unzip -o life-style-data.zip

# Load CSV into pandas
import pandas as pd
df = pd.read_csv('Final_data.csv')
df.head(5)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/jockeroika/life-style-data
# License(s): apache-2.0
# life-style-data.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  life-style-data.zip
#   inflating: Final_data.csv
#   inflating: meal_metadata.csv
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0  34.91    Male        65.27        1.62   188.58   157.65        69.05
# 1  23.37  Female        56.41        1.55   179.43   131.75        73.18
# 2  33.20  Female        58.98        1.67   175.04   123.95        54.96
# 3  38.69  Female        93.78        1.70   191.21   155.10        50.07
# 4  45.09    Male        52.42        1.88   193.58   152.88        70.84
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  ...  \
# 0                      1.00          1080.90     Strength  ...
# 1                      1.37          1809.91         HIIT  ...
# ...

# %%
# From Github (no nee flecch data)

URL = ('https://raw.githubusercontent.com/Sutanoy/Public-Regression-Datasets/refs/heads/main/Breatscancer_dataset2.csv')
df = pd.read_csv(URL)
df.head(2)
# Out:
#    ID  Age        BMI  Glucose  Insulin      HOMA  Leptin  Adiponectin  \
# 0   1   48  23.500000       70    2.707  0.467409  8.8071     9.702400
# 1   2   83  20.690495       92    3.115  0.706897  8.8438     5.429285
#
#    Resistin    MCP.1  Classification
# 0   7.99585  417.114               0
# 1   4.06405  468.786               0

# %%
# link: https://www.kaggle.com/datasets/jaderz/hospital-beds-management

# %%
# from kaggle (need to flech data)
from google.colab import files

# Upload your kaggle.json from Windows
files.upload()

# Configure Kaggle credentials
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# Download dataset using slug
    #URL = ('/kaggle/input/hospital-beds-management/patients.csv') from kaggle
    #Auhtor: jaderz
    #Dataset name: hospital-beds-management/patients
# !kaggle datasets download -d jaderz/hospital-beds-management

# Unzip the file
# !unzip -o hospital-beds-management.zip

# Load CSV into pandas
import pandas as pd
df = pd.read_csv('patients.csv')
df.head(2)
# Out:
#      <input type="file" id="files-1515a2ba-38b4-43e4-b700-62c42bb2aef0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1515a2ba-38b4-43e4-b700-62c42bb2aef0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df_services = pd.read_csv('services_weekly.csv')
df_patients = pd.read_csv('patients.csv')
df_staff = pd.read_csv('staff.csv')
df_schedule = pd.read_csv('staff_schedule.csv')

# %%
df_services.head(2)
# Out:
#    week  month    service  available_beds  patients_request  \
# 0     1      1  emergency              32                76
# 1     1      1    surgery              45               130
#
#    patients_admitted  patients_refused  patient_satisfaction  staff_morale  \
# 0                 32                44                    67            70
# 1                 45                85                    83            78
#
#   event
# 0  none
# 1   flu

# %%
df_patients.head(2)
# Out:
#      patient_id               name  age arrival_date departure_date  service  \
# 0  PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22  surgery
# 1  PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14  surgery
#
#    satisfaction
# 0            61
# 1            83

# %%
df_schedule.head(2)
# Out:
#    week      staff_id    staff_name    role    service  present
# 0     1  STF-b77cdc60  Allison Hill  doctor  emergency        1
# 1     2  STF-b77cdc60  Allison Hill  doctor  emergency        1

# %%
# ready-to-run Colab snippet

# %%
# 1️⃣ Install Kaggle API
# !pip install kaggle

# 2️⃣ Upload your Kaggle API key (kaggle.json)
from google.colab import files
files.upload()  # choose kaggle.json from your computer

# 3️⃣ Configure Kaggle credentials
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# 4️⃣ Download the dataset
# !kaggle datasets download -d jaderz/hospital-beds-management

# 5️⃣ Unzip the dataset
# !unzip -o hospital-beds-management.zip

# 6️⃣ Import pandas and load all CSVs
import pandas as pd

csv_files = ['patients.csv', 'staff.csv', 'services_weekly.csv']
dfs = {f: pd.read_csv(f) for f in csv_files}  # dictionary of DataFrames

# 7️⃣ Check first rows of each
for name, df in dfs.items():
    print(f"===== {name} =====")
    print(df.head(2), "\n")
# Out:
# ...
#      <input type="file" id="files-4150027f-a3b8-417f-89e9-0ef217dc961e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4150027f-a3b8-417f-89e9-0ef217dc961e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
